# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 18 10:26:42 2016

@author: mac
"""
import urllib
import re
import os
import socket
def schedule(a,b,c):
  '''''
  a:已经下载的数据块
  b:数据块的大小
  c:远程文件的大小
   '''
  per = 100.0 * a * b / c
  if per > 100 :
    per = 100
  print '%.2f%%' % per

def getHtml(url):
  page = urllib.urlopen(url)
  html = page.read()
  return html
def downloadImg(html,logoname,count):
  reg = r'"objURL":"(.*?)"'    #正则表达式匹配
  imgre = re.compile(reg)
  imglist = re.findall(imgre, html)
  #定义文件夹的名字
  picpath = 'logo_img/%s/' % (logoname) #下载到的本地目录
  
  if not os.path.exists(picpath):   #路径不存在时创建一个
    os.makedirs(picpath)   
  x = 0
  socket.setdefaulttimeout(10)#设置防止下载时间超时10s
  for imgurl in imglist:
    target = picpath+'%s.jpg' % count
    print 'Downloading image to location: ' + target + '\nurl=' + imgurl
    try:    
        image = urllib.urlretrieve(imgurl, target, schedule)
        x += 1
        count += 1
        #print "count =========" + str(count)#当前logo下载的数量
    except:
        continue
  return image,count;
if __name__ == "__main__":
    f = open("/Users/mac/logo_detection/paste_img/flickr-32.txt", "r")  #logo_name2.txt内每行存放需要获取的图片关键字
    while True:
        logoname = f.readline()
        logoname = logoname[:-1]
        page = 0;
        if logoname:
            #print logoname
            count = 0
            try:
                while(count<400):#设置需要下载图片的数目
                    html = getHtml("http://image.baidu.com/search/flip?tn=baiduimage&ie=utf-8&word=%s&pn=%d"%(logoname,page))          
                    image,count = downloadImg(html,logoname,count) 
                    page += 20
            except:
                continue
        else:
            break
    print "Download has finished."
# Out:
# Downloading image to location: logo_img/chimay logo/0.jpg
# url=http://img.wadongxi.net/shop/67/b3/7b9f74ecc5f81b3.jpg
# 0.00%
# 12.83%
# 25.65%
# 38.48%
# 51.31%
# 64.13%
# 76.96%
# 89.79%
# 100.00%
# Downloading image to location: logo_img/chimay logo/1.jpg
# url=http://img02.tooopen.com/font/thumbnails/2010/5/7/x_20100507110157221723.jpg
# 0.00%
# 100.00%
# Downloading image to location: logo_img/chimay logo/2.jpg
# url=http://img.25pp.com/uploadfile/soft/images/2015/0616/20150616022655612.jpeg
# 0.00%
# 8.45%
# 16.90%
# 25.35%
# 33.80%
# 42.25%
# 50.70%
# 59.15%
# 67.59%
# 76.04%
# 84.49%
# 92.94%
# 100.00%
# Downloading image to location: logo_img/chimay logo/3.jpg
# url=http://www.epermarket.com/resource/PoductPicTemp/P601/New.472995ee-9399-482e-a360-6dbcc6b5882bSource.jpg
# 0.00%
# 11.56%
# 23.11%
# 34.67%
# 46.22%
# 57.78%
# 69.34%
# 80.89%
# 92.45%
# 100.00%
# Downloading image to location: logo_img/chimay logo/4.jpg
# url=http://img.mp.itc.cn/upload/20160719/b335a39ee224450bb9696b648545c0cc.jpg
# 0.00%
# 51.96%
# 100.00%
# Downloading image to location: logo_img/chimay logo/5.jpg
# url=http://picm.photophoto.cn/010/067/011/0670110010.jpg
# 0.00%
# 14.31%
# 28.62%
# 42.93%
# 57.24%
# 71.54%
# 85.85%
# 100.00%
# Downloading image to location: logo_img/chimay logo/6.jpg
# url=http://img3.redocn.com/20130114/Redocn_2013011413074480.jpg
# 0.00%
# 7.50%
# 14.99%
# 22.49%
# 29.99%
# 37.48%
# 44.98%
# 52.48%
# 59.98%
# 67.47%
# 74.97%
# 82.47%
# 89.96%
# 97.46%
# 100.00%
# Downloading image to location: logo_img/chimay logo/7.jpg
# url=http://blogfile.ifeng.com/uploadfiles/blog_attachment/0811/56/1041756_d0a595918fd402e5e3b8136bb77f4b20.jpg
# 0.00%
# 37.56%
# 75.11%
# 100.00%
# Downloading image to location: logo_img/chimay logo/8.jpg
# url=http://image.tupian114.com/20130114/07443121.jpg.thumb.jpg
# 0.00%
# 80.69%
# 100.00%
# Downloading image to location: logo_img/chimay logo/9.jpg
# url=http://s11.sinaimg.cn/mw690/003RfU6azy6LymeaEe6da
# 0.00%
# 9.72%
# 19.44%
# 29.17%
# 38.89%
# 48.61%
# 58.33%
# 68.06%
# 77.78%
# 87.50%
# 97.22%
# 100.00%
# Downloading image to location: logo_img/chimay logo/10.jpg
# url=http://imgqn.koudaitong.com/upload_files/2014/12/11/141831286349952027.jpg
# 0.00%
# 5.88%
# 11.76%
# 17.64%
# 23.52%
# 29.40%
# 35.28%
# 41.16%
# 47.04%
# 52.92%
# 58.80%
# 64.68%
# 70.56%
# 76.44%
# 82.33%
# 88.21%
# 94.09%
# 99.97%
# 100.00%
# Downloading image to location: logo_img/chimay logo/11.jpg
# url=http://come2list.com/services/files/617/MTUyZTllZDc%3D.jpg
# 0.00%
# 100.00%
# Downloading image to location: logo_img/chimay logo/12.jpg
# url=http://img9.ph.126.net/gSVSS60U1Pv4G5bRwN6Ayg==/1350798413251902469.jpg
# 0.00%
# 3.86%
# 7.73%
# 11.59%
# 15.45%
# 19.31%
# 23.18%
# 27.04%
# 30.90%
# 34.76%
# 38.63%
# 42.49%
# 46.35%
# 50.22%
# 54.08%
# 57.94%
# 61.80%
# 65.67%
# 69.53%
# 73.39%
# 77.25%
# 81.12%
# 84.98%
# 88.84%
# 92.70%
# 96.57%
# 100.00%
# Downloading image to location: logo_img/chimay logo/13.jpg
# url=http://img.mp.itc.cn/upload/20160320/c3a3eb8f3875463fa46e9e6682130cc9.jpg
# 0.00%
# 30.22%
# 60.45%
# 90.67%
# 100.00%
# Downloading image to location: logo_img/chimay logo/14.jpg
# url=http://ec4.images-amazon.com/images/I/41vmSj6jJ6L._SX342_.jpg
# 0.00%
# 63.20%
# 100.00%
# Downloading image to location: logo_img/chimay logo/15.jpg
# url=http://www.t-jiu.com/tujiuJDAwMSQxMS84Njg2ODY4MDAvVDJGSEd3WGc0YiQ2JDZfISE4Njg2ODY4MDAkOQ.jpg
# 0.00%
# 28.52%
# 57.04%
# 85.57%
# 100.00%
# Downloading image to location: logo_img/chimay logo/16.jpg
# url=http://d6.yihaodianimg.com/N01/M04/48/1E/CgQCrlLg7PCAfVUCAAGKVm_Jhpk62300.jpg
# 0.00%
# 11.82%
# 23.64%
# 35.46%
# 47.28%
# 59.09%
# 70.91%
# 82.73%
# 94.55%
# 100.00%
# Downloading image to location: logo_img/chimay logo/17.jpg
# url=http://www.t-cha.com/tutcJDAwNCQxNC84Njg2ODY4MDAvVDJnaExhWGUkNTg2ODY4NjgwMCQ5.jpg
# 0.00%
# 12.62%
# 25.24%
# 37.86%
# 50.47%
# 63.09%
# 75.71%
# 88.33%
# 100.00%
# Downloading image to location: logo_img/chimay logo/18.jpg
# url=http://thumbs.dreamstime.com/x/chimayo-nm-45993347.jpg
# Downloading image to location: logo_img/chimay logo/18.jpg
# url=http://www.t-jiu.com/tujiuJDAwMy50YW9iYW9jZG4uY29tL2Jhby91cGxvYWRlZC9pMy8xMzM3NzAyNjU1MzQ0NzcwNC9UMTlfd0JYbU5lJDYkNl8hISQz.jpg
# Downloading image to location: logo_img/chimay logo/18.jpg
# url=http://img.wadongxi.net/shop/54/92/c27aa1898d93d92.jpg
# 0.00%
# 26.36%
# 52.72%
# 79.08%
# 100.00%
# Downloading image to location: logo_img/chimay logo/19.jpg
# url=http://image1.ocj.com.cn/item_images/item/18/69/13/186913L.jpg
# 0.00%
# 23.53%
# 47.07%
# 70.60%
# 94.14%
# 100.00%
# Downloading image to location: logo_img/chimay logo/20.jpg
# url=http://image.tupian114.com/20130114/07443121.jpg
# 0.00%
# 11.76%
# 23.51%
# 35.27%
# 47.03%
# 58.78%
# 70.54%
# 82.30%
# 94.05%
# 100.00%
# Downloading image to location: logo_img/chimay logo/21.jpg
# url=http://www.stpeterslist.com/wp-content/uploads/2011/08/trapppist.png
# 0.00%
# 12.68%
# 25.36%
# 38.03%
# 50.71%
# 63.39%
# 76.07%
# 88.74%
# 100.00%
# Downloading image to location: logo_img/chimay logo/22.jpg
# url=http://pic192.gtobal.com/image1/F5/63/wKgSE1Hp5fmAP0_tAAG-t5fI4XU763.jpg
# 0.00%
# 7.16%
# 14.33%
# 21.49%
# 28.65%
# 35.82%
# 42.98%
# 50.14%
# 57.31%
# 64.47%
# 71.63%
# 78.80%
# 85.96%
# 93.12%
# 100.00%
# Downloading image to location: logo_img/chimay logo/23.jpg
# url=http://img5.makepolo.net/images/formals/medium_img/product/839/768/medium_da1f87d0c47c24495ad642589168565d.jpg
# 0.00%
# 98.85%
# 100.00%
# Downloading image to location: logo_img/chimay logo/24.jpg
# url=http://www.so-b.com/tusbJDAwMy50YW9iYW9jZG4uY29tL2Jhby91cGxvYWRlZC9pMy8xMzM3NzAyMjA1MDkxNDI3Ni9UMWZUQ2lYdHhmJDYkNl8hISQz.jpg
# 0.00%
# 1.91%
# 3.82%
# 5.73%
# 7.64%
# 9.55%
# 11.45%
# 13.36%
# 15.27%
# 17.18%
# 19.09%
# 21.00%
# 22.91%
# 24.82%
# 26.73%
# 28.64%
